# %% [markdown]
# # Module 7 · Compose the multi-agent flow
#
# We built six deterministic specialist skills. Now we **compose** them into one orchestrator,
# `/decide`, that takes the messy drill-down question and runs a **fixed, gated sequence** —
# refusing to conclude early or anchor on the framing:
#
# ```
# profile → effective-n → significance(cluster) → bayesian-update → trend → budget → SYNTHESIS
# ```
#
# The individual statistics a strong model can already do. What it will **not** reproduce from a
# terse prompt is this **procedure** — which tests, in what order, with which gates. That procedure
# is the institutional knowledge the skill encodes. The analyst supplies the question; the flow
# guarantees the floor.

# %% [markdown]
# ## Run the orchestrator on our Bing question
# Each step below is a real specialist skill (its own reviewed, seeded script) invoked in order.

# %%
import sys, subprocess, os
DECIDE = r"/home/am/projects/natural-intelligence/new_workshop/.claude/skills"
out = subprocess.run([sys.executable, os.path.join(DECIDE, "decide", "decide.py"),
                      "--a", "Summit Direct Business", "--b", "Cedar Business Bank",
                      "--slice", "channel=Bing"], capture_output=True, text=True)
print(out.stdout)
# Out:
# ========================================================================
# DECISION MEMO — gated statistical procedure (deterministic)
# ========================================================================
# Q: In ['channel=Bing'], does 'Summit Direct Business' beat 'Cedar Business Bank' on EPC enough to reorder the chart?
# Each step GATES the next. We do not anchor on the framing or conclude early.
#
# ────────────────────────────────────────────────────────────────────────
# STEP 1 · PROFILE the metric — is its mean trustworthy?
# ────────────────────────────────────────────────────────────────────────
# PROFILE · metric='revenue' · grain=click · slice=['channel=Bing']
#
# ────────────────────────────────────────────────────────────────────────
# whole slice
# ────────────────────────────────────────────────────────────────────────
#   n=15,783  mean=5.022  median=0.000  trimmed(10%)=1.463
#   skew=12.3  zero-share=78.5%  top-1% share=24.8%  max=594.9
#
# ────────────────────────────────────────────────────────────────────────
# VALIDATION — can you trust an average of this?
# ────────────────────────────────────────────────────────────────────────
#   🚩 Heavy skew (skew=12.3). The MEAN is not a typical value. Do NOT use a t-test / normal CI — use bootstrap or rank methods (see /significance-check).
#   🚩 Whale-driven: the top 1% of rows hold 25% of all revenue. A few conversions can invent a difference — plot the distribution first.
#   🚩 79% of rows are exactly 0 (zero-inflated); the mean blends 'did it convert' with 'how much'.
#
# ────────────────────────────────────────────────────────────────────────
# EFFECTIVE-N — is every row independent?
# ────────────────────────────────────────────────────────────────────────
#   rows=15,783  visits(clusters)=13,355  mean rows/visit=1.18  ICC=0.415
#   design effect deff=1.076  →  effective n ≈ 14,675 (93% of nominal)
#   🚩 Click-outs share visits → NOT i.i.d. Treat n as ~14,675, and use the CLUSTER bootstrap (resample visits, not rows) for any CI.
#   GATE ▸ EPC is zero-inflated & whale-skewed ⇒ use bootstrap/rank, never a t-test.
#
# ────────────────────────────────────────────────────────────────────────
# STEP 2 · TEST the claim (cluster-aware) — is the difference real?
# ────────────────────────────────────────────────────────────────────────
# SIGNIFICANCE · 'revenue' · partner: Summit Direct Business vs Cedar Business Bank · slice=['channel=Bing']
#
# ────────────────────────────────────────────────────────────────────────
# TEST CHOSEN: Mann-Whitney U + CLUSTER bootstrap (resampling visits)
# ────────────────────────────────────────────────────────────────────────
#   Summit Direct Business: mean=10.483 median=0.000 skew=7.3 (n=431)
#   Cedar Business Bank: mean=8.158 median=0.000 skew=7.0 (n=838)
#   mean diff = +2.325   95% CI [-2.406, +7.778]
#   Welch t p = 0.3672   Mann-Whitney p = 0.1414   Cohen d = 0.058
#
# ────────────────────────────────────────────────────────────────────────
# VALIDATION
# ────────────────────────────────────────────────────────────────────────
#   🚩 Heavy-tailed (skew 7.3/7.0) → t-test invalid. Primary test is Mann-Whitney; the interval is a BOOTSTRAP. If a tool gave only a t-test p here, that is the #1 pitfall.
#   ✅ Clustered CI used (deff≈1.02); rows share visits, so the row-level interval would be too narrow.
#   🚩 Bootstrap CI for the difference INCLUDES 0 — not a reliable difference. On a thin slice this is the honest verdict: coin-flip.
#   ⚠️  n-trap: with large n almost any gap is 'significant'. Lead with effect size + CI.
#   GATE ▸ CI straddles 0 → COIN-FLIP on this slice. Do not conclude. Bring in a prior.
#
# ────────────────────────────────────────────────────────────────────────
# STEP 3 · BAYESIAN INFERENCE — does the flip survive an informative prior?
# ────────────────────────────────────────────────────────────────────────
# BAYESIAN INFERENCE · 'revenue' · Summit Direct Business vs Cedar Business Bank · slice=['channel=Bing'] · prior=other-slice
#
# ────────────────────────────────────────────────────────────────────────
# Summit Direct Business
# ────────────────────────────────────────────────────────────────────────
#   thin slice : 10.48  (n=431)
#   prior      : 8.10  (n=1,710)  ← other-slice
#   POSTERIOR  : 8.39  95% CI [6.86, 9.92]
#
# ────────────────────────────────────────────────────────────────────────
# Cedar Business Bank
# ────────────────────────────────────────────────────────────────────────
#   thin slice : 8.16  (n=838)
#   prior      : 9.97  (n=3,384)  ← other-slice
#   POSTERIOR  : 8.64  95% CI [6.53, 10.76]
#
# ────────────────────────────────────────────────────────────────────────
# DECISION (posterior)
# ────────────────────────────────────────────────────────────────────────
#   raw slice ordering : Summit Direct Business > Cedar Business Bank  (10.48 vs 8.16)
#   posterior ordering : Summit Direct Business < Cedar Business Bank  (8.39 vs 8.64)
#   P(Summit Direct Business > Cedar Business Bank) = 43%   expected loss if we pick Summit Direct Business: 0.667/click
#
# ────────────────────────────────────────────────────────────────────────
# VALIDATION
# ────────────────────────────────────────────────────────────────────────
#   🚩 The slice ordering REVERSES once anchored on history — the apparent win was regression to the mean. Do NOT reorder on this slice alone.
#   ⚠️  A prior only helps if the past is representative (stationarity). If a regime break is suspected, validate with /trend-check before trusting it — else the prior biases you.
#   GATE ▸ posterior REVERSES the slice ordering → the flip was regression to the mean.
#
# ────────────────────────────────────────────────────────────────────────
# STEP 4 · TREND / STATIONARITY — is the prior even valid?
# ────────────────────────────────────────────────────────────────────────
# TREND-CHECK · EPC · slice=['channel=Bing']
#
# ────────────────────────────────────────────────────────────────────────
# LATEST DAY vs NORMAL VARIATION
# ────────────────────────────────────────────────────────────────────────
#   latest (2026-05-30, Sat): 3.08
#   month mean: 5.05   normal band (±2σ): [1.67, 8.44]
#   Sat baseline: 5.19 (±2σ = ±4.78)
#   last 7d mean 4.42 vs prior 5.11  (regime z=-1.06)
#
# ────────────────────────────────────────────────────────────────────────
# VALIDATION — is the move real?
# ────────────────────────────────────────────────────────────────────────
#   ✅ Latest is INSIDE the normal monthly band — nothing to react to; this is ordinary day-to-day variation.
#   ✅ Normal for a Sat — remember weekdays differ; don't compare across days.
#   ✅ No regime break: recent period is consistent with history — a prior is safe to use.
#   ⚠️  One low day is not a trend. Always place it against seasonality and the monthly band before escalating.
#   GATE ▸ no regime break ⇒ the historical prior is safe to lean on.
#
# ────────────────────────────────────────────────────────────────────────
# STEP 5 · REFRAME to the decision metric — profit/visit, not EPC alone
# ────────────────────────────────────────────────────────────────────────
# BUDGET DECISION · profit per visit by channel × platform
#
# ────────────────────────────────────────────────────────────────────────
# FUNNEL (EPV interval is bootstrap 95%)
# ────────────────────────────────────────────────────────────────────────
#   Organic  desktop     visits= 15,332  conv=11.63%  EPV=3.257[2.68,4.21]  CPV=0.053  profit/visit=+3.204
#   Organic  mobile      visits= 21,049  conv=8.95%  EPV=2.151[1.95,2.43]  CPV=0.045  profit/visit=+2.106
#   Bing  desktop        visits= 17,621  conv=10.44%  EPV=2.480[2.31,2.66]  CPV=1.945  profit/visit=+0.535
#   Bing  mobile         visits= 17,327  conv=8.25%  EPV=2.053[1.88,2.24]  CPV=1.663  profit/visit=+0.390
#   Social  desktop      visits=  6,120  conv=6.29%  EPV=1.436[1.23,1.67]  CPV=1.215  profit/visit=+0.220
#   Google  desktop      visits= 35,748  conv=11.89%  EPV=3.013[2.85,3.19]  CPV=2.866  profit/visit=+0.148
#   Social  mobile       visits= 21,663  conv=4.91%  EPV=1.106[1.01,1.21]  CPV=1.041  profit/visit=+0.065
#   Google  mobile       visits= 45,140  conv=9.00%  EPV=2.231[2.09,2.40]  CPV=2.442  profit/visit=-0.210  ← LOSES money
#
# ────────────────────────────────────────────────────────────────────────
# VALIDATION — answer honestly
# ────────────────────────────────────────────────────────────────────────
#   Conversion: Google 10.27% vs Bing 9.35% (diff +0.92pp, p=1.5e-06).
#   🚩 Conversion rate is the WRONG yardstick — it ignores cost and revenue size. Decide on PROFIT PER VISIT (EPV − CPV), which the table ranks.
#   ⚠️  Cost is aggregate (no per-user cost) → CPV is an average; you cannot attribute cost to a single visit. Confirm any big reallocation with a small holdout before scaling.
#   GATE ▸ rank on profit/visit (EPV−CPV); a per-click EPC gap is not a budget mandate.
#
# ────────────────────────────────────────────────────────────────────────
# SYNTHESIS — recommendation (grounded in the gated steps)
# ────────────────────────────────────────────────────────────────────────
#   • Do NOT reorder the chart for ['channel=Bing']. The apparent 'Summit Direct Business > Cedar Business Bank' is a thin-slice coin-flip (CI includes 0), and anchoring on history REVERSES it — regression to the mean.
#   • Decide on profit/visit, not EPC or conversion in a single slice.
#
# ────────────────────────────────────────────────────────────────────────
# WHAT WE DID NOT ESTABLISH (honesty gate)
# ────────────────────────────────────────────────────────────────────────
#   • Causality — observational, no A/B; cost is aggregate (no per-visit cost).
#   • Stability — a slice ordering next month may differ. Confirm any real move with a holdout.

# %% [markdown]
# ## The payoff — why deterministic composition beats re-asking
#
# **Reproducibility:** the whole procedure is seeded. Run it twice → **byte-identical** output. You
# can't build a team process on an analysis that wanders each run.

# %%
r1 = subprocess.run([sys.executable, os.path.join(DECIDE, "decide", "decide.py")],
                    capture_output=True, text=True).stdout
r2 = subprocess.run([sys.executable, os.path.join(DECIDE, "decide", "decide.py")],
                    capture_output=True, text=True).stdout
print("Two independent runs identical:", r1 == r2)
assert r1 == r2
# Out:
# Two independent runs identical: True

# %% [markdown]
# ## What the flow established (and what it refused to)
#
# - **The honest verdict:** in Bing, *Summit Direct Business > Cedar* is a **thin-slice coin-flip**
#   (cluster-bootstrap CI includes 0), and anchoring on history **reverses** it — regression to the
#   mean. **Do not reorder the chart for Bing.**
# - **Decide on profit/visit**, not a single-slice EPC or conversion gap.
# - **What we did NOT establish:** causality (observational, no A/B), per-visit cost (aggregate only),
#   and stability over time. Confirm any real move with a small holdout.
#
# **The value the orchestrator adds over re-asking an LLM:**
#
# | Property | Ad-hoc LLM analysis | Deterministic `/decide` |
# |---|---|---|
# | Same path every run | ✗ varies | ✓ fixed, gated |
# | Byte-identical output | ✗ | ✓ seeded |
# | Right test for the shape | sometimes | ✓ always |
# | Respects clustering / effective-n | rarely | ✓ built-in |
# | Cost per run | re-reasons every time | ~free compute |
# | Auditable | ✗ | ✓ short reviewed code |
#
# The analyst guarantees the **right question**; the tool guarantees the **floor**. That is the
# workshop.
